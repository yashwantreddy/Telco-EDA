# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (20.0,10.0)

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
gender_palette = ["#e6acc4", "#6dcff6"]
senior_palette = ["#922d20", "#6dc066"]

# %%
sns.countplot(df.gender, palette=gender_palette)

# %% [markdown]
# ### Seems like we have an almost equal numbers of male and female customers - with a slightly higher number of overall male customers

# %%
sns.countplot(df.SeniorCitizen, palette=senior_palette)

# %% [markdown]
# ### There aren't a lot of senior citizens, about 1 senior citizen in 6 customers

# %%
sns.countplot(df.SeniorCitizen, hue=df.gender, palette=gender_palette)

# %% [markdown]
# ### Almost a 48-52 split in the genders of senior and non-senior citizens, with the male customers being the majority.

# %%
sns.countplot(df.Partner, palette=["#95a5a6", "#e74c3c"])

# %% [markdown]
# ### Again almost a 50-50 split here with customers being married or not. There is a slightly higher number of unmarried customers.

# %%
sns.countplot(df.Partner, hue=df.gender, palette=gender_palette)

# %% [markdown]
# ### Interestingly there are a higher number of unmarried male and female customers

# %%
sns.countplot(df.Dependents, palette=["#34495e", "#2ecc71"])

# %% [markdown]
# ### 3/4 of the customers in this dataset do not have any Dependents.

# %%
sns.countplot(df.tenure, palette="GnBu_d")

# %% [markdown]
# ### There seems to be over 600 customers who have used the service for just 1 day. The next highest set of customers are the ones who have stayed loyal to the service - in this case around 72 days. This clearly implies that either customers hate this service or love it.

# %%
sns.countplot(df.tenure, hue=df.gender, palette=gender_palette)

# %% [markdown]
# ### One insight that we can draw from this distribution is that female customers are a majority in staying with the service for 1+ days up until 15 days since start of service.

# %%
sns.boxplot(x = df.gender, y =df.tenure, palette=gender_palette)

# %% [markdown]
# ### This boxplot distribution ensures that both the genders have a very similar tensure quartlies, with male customers having a 1% higher overall quartile range

# %%
sns.countplot(df.PhoneService, palette=["#ff6600", "#99cc33"])

# %%
sns.countplot(df.MultipleLines, palette=["#922d20", "#6b6767", "#ffc300"])

# %% [markdown]
# ### Around 40% of the customers have multiple phone lines, while 50% dont have multiple phone lines and 10% don't even have a phone service!

# %%
sns.countplot(df.InternetService, palette=["#00ac77", "#7e1b9d", "#ff007c"])

# %% [markdown]
# ### 42% of the customer base have the fiber optic internet set up, while around 38% have the traditional DSL and 20% dont even have the internet service - they just have a phone line from the service.

# %%
sns.countplot(df.InternetService, hue=df.PhoneService, palette=["#ff6600", "#99cc33"])

# %% [markdown]
# ### This kinda reinforces the fact that Fiber optic connection grants a phone service directly. Also note that some of the subscribers of DSL do NOT have an active phone service. They probably just want the basic internet plan without the phone service.

# %%
sns.countplot(df.InternetService, hue=df.SeniorCitizen, palette=senior_palette)

# %% [markdown]
# ### It seems like our grandparents are catching up! A large majority of senior citizens are subscribed to the fiber optic plan as compared to the traditional DSL modem!

# %%
sns.countplot(df.OnlineSecurity, palette=["#00bfff", "#6b6767", "#11011a"])

# %% [markdown]
# ### 50% of the customer base have not opted for the Online security feature of the service, while 27% have opted for that feature, a good 23% do not even have the internet service.

# %%
sns.countplot(df.OnlineBackup, palette=["#ff4444", "#fef65b", "#ff1493"])

# %% [markdown]
# ### There's a larger portion of the customer base who have opted for Online Backup than opting for Online Security

# %%
sns.countplot(df.InternetService, hue=df.OnlineSecurity, palette=["#00bfff", "#6b6767", "#11011a"])

# %% [markdown]
# ### Almost 50% of the DSL subcribers have Online Security while only 30% Fiber Optic subscribers have opted for it

# %%
sns.countplot(df.DeviceProtection, palette=["#daa520", "#ffff66", "#cbbeb5"])

# %% [markdown]
# ### Around 60% of subscribers with Internet service have not opted for Device Protection.

# %%
sns.countplot(df.TechSupport, palette=["#0e2f44", "#afeeee", "#dddddd"])

# %% [markdown]
# ### Surprising to see quite a large number of the customer base opting in for tech support

# %%
sns.countplot(df.StreamingMovies, hue=df.StreamingTV, palette=["#3E2723", "#8D6E63", "#B71C1C"])

# %% [markdown]
# ### Customers usually subscribe for Streaming TV or Streaming Movies or both together. Customers who dont have Streaming TV also dont opt for Streaming Movies. Customers who dont have one of the two, don't usually opt for the other.

# %%
sns.countplot(df.Contract, hue=df.SeniorCitizen, palette=senior_palette)

# %% [markdown]
# ### Senior Citizens seem to be favoring monthly contracts. No long term benefits, I guess!

# %%
sns.countplot(df.PaperlessBilling, hue=df.gender, palette=gender_palette)

# %% [markdown]
# ### Interestingly exactly the same number of male and female customers have opted for paperless billing

# %%
sns.countplot(df.PaperlessBilling, hue=df.SeniorCitizen, palette=senior_palette)

# %% [markdown]
# ### A majority of Senior Citizens have opted for Paperless billing - moving away from the traditional bills arriving through post - which is great!

# %%
sns.countplot(df.PaymentMethod, hue=df.gender, palette=gender_palette)

# %% [markdown]
# ### One point to note is that female customers dominate the automatic bank transfer category as compared to male customers

# %%
sns.countplot(df.PaymentMethod, hue=df.SeniorCitizen, palette=senior_palette)

# %% [markdown]
# ### Senior citizens have a minority and mailed check - which intuitively is more laborous than the rest of the options.

# %%
sns.countplot(df.MonthlyCharges, palette="Blues_d")

# %% [markdown]
# ### There seems to be a value that is most common - over 60 customers have paid this amount. Some of the other values are recurring too.

# %%
sns.distplot(df.MonthlyCharges, bins=10, color="#6dc066")

# %% [markdown]
# ### This distributions says that most of the customers who pay the basic plan - which could be $20 and a few values around it, along with prices around 75-100 - where the major part of the distribution lies. The other small maximas are probably the other famous plan prices, while some monthly charges are slightly absurd at over 120 (for over usage maybe)

# %%
clean = df.TotalCharges.convert_objects(convert_numeric=True)
# Out:
# C:\Users\yashwant.jankay\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
clean[clean.isna()]
# Out:
# 488    NaN
# 753    NaN
# 936    NaN
# 1082   NaN
# 1340   NaN
# 3331   NaN
# 3826   NaN
# 4380   NaN
# 5218   NaN
# 6670   NaN
# 6754   NaN
# Name: TotalCharges, dtype: float64

# %%
clean = clean.dropna()

# %%
clean_df = df.TotalCharges.convert_objects(convert_numeric=True)
# Out:
# C:\Users\yashwant.jankay\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
clean_df = df[clean_df.notna()]

# %%
clean_df.reset_index(inplace=True)

# %%
sns.distplot(clean, color="#800000")

# %% [markdown]
# ### Total charges over 2000? over 4000? over 6000? Even over 8000 - we have them all! That's completely absurd.

# %%
sns.relplot(x = "TotalCharges", y = "Churn", data=clean_df)

# %% [markdown]
# ### There doesnt seem to be any correlation between the total bill to a customer and their churn.

# %%
clean_df.sample(10)
# Out:
#       index  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 984     987  3717-OFRTN    Male              0      No         No       1
# 2814   2819  1575-KRZZE  Female              0      No         No       4
# 4736   4744  6139-ZZRBQ    Male              1      No         No      64
# 3075   3080  1777-JYQPJ    Male              0      No         No       2
# 1924   1929  2018-QKYGT    Male              0     Yes        Yes       1
# 944     947  9904-EHEVJ  Female              1     Yes        Yes      32
# 444     444  1910-FMXJM  Female              0     Yes         No      36
# 2160   2165  5039-LZRQT  Female              0      No         No      13
# 2862   2867  7244-KXYZN  Female              0      No         No      24
# 3383   3389  9617-INGJY    Male              0      No         No       1
#
#      PhoneService     MultipleLines InternetService  ...    \
# 984           Yes                No              No  ...
# ...

# %%
clean_df.columns
# Out:
# Index(['index', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
#Features/columns with categoricals -
cats = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 
        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

# %%
onehots = pd.get_dummies(clean_df[cats], drop_first=True)

# %%
final = pd.concat([clean_df, onehots], axis=1)

# %%
feats = final.drop('Churn', axis=1)

# %%
y = final.Churn_Yes

# %%
clean_df.columns
# Out:
# Index(['index', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
X = final.drop(['index', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
       'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod',
       'Churn', 'Churn_Yes'], axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
preds = rf.predict(X_test)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.7690650581645843

# %%
cm = confusion_matrix(y_test, preds)

# %%
cm
# Out:
# array([[1516,  195],
#        [ 341,  269]], dtype=int64)

# %%
def plot_confusion_matrix(confusion_mat):    
    plt.clf()
    plt.imshow(confusion_mat, interpolation='nearest', cmap=plt.cm.Wistia)
    classNames = ['Negative Class','Positive Class']
    plt.title('Churn or no Churn')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    tick_marks = np.arange(len(classNames))
    plt.xticks(tick_marks, classNames, rotation=45)
    plt.yticks(tick_marks, classNames)
    s = [['TN','FP'], ['FN', 'TP']]
    for i in range(2):
        for j in range(2):
            plt.text(j,i, str(s[i][j])+" = "+str(confusion_mat[i][j]))
    plt.show()

# %%
plot_confusion_matrix(cm)

# %%
final.Churn.value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
roc_auc_score(y_test, preds)
# Out:
# 0.6635075835241591

# %%
for i in range(len(X.columns)):
    print(rf.feature_importances_[i], 'associated with ', X.columns[i])
# Out:
# 0.20701743086289456 associated with  MonthlyCharges
# 0.27816842762340876 associated with  TotalCharges
# 0.032026436205777165 associated with  gender_Male
# 0.02611347911189834 associated with  Partner_Yes
# 0.022198757695337062 associated with  Dependents_Yes
# 0.00457673592192015 associated with  PhoneService_Yes
# 0.004339497235895307 associated with  MultipleLines_No phone service
# 0.023788809229056924 associated with  MultipleLines_Yes
# 0.046119474406318826 associated with  InternetService_Fiber optic
# 0.012915266691670296 associated with  InternetService_No
# 0.008806522700515329 associated with  OnlineSecurity_No internet service
# 0.031851735029989996 associated with  OnlineSecurity_Yes
# 0.008444893503225095 associated with  OnlineBackup_No internet service
# 0.025099949667393824 associated with  OnlineBackup_Yes
# 0.007349351500096429 associated with  DeviceProtection_No internet service
# 0.023336601067190644 associated with  DeviceProtection_Yes
# ...

# %%
sns.relplot(x = "TotalCharges", y = "Churn", data=clean_df, hue="InternetService", aspect=3, height=7)

# %% [markdown]
# ### Now this is cool. Here we observe a majority of orange dots at the top. This implies that people who have opted for the Fiber optic connection have a higher churn rate. And this trend is constant throughout - for the smallest charges to the largest monthly bills.

# %%
sns.relplot(x = "MonthlyCharges", y = "TotalCharges", data=clean_df, hue="InternetService", aspect=2, height=9)

# %% [markdown]
# ### Beautiful. Here is the relationship between Monthly Charges, Total Charges and Internet Service. It's fair to see Fiber Optic customers being on the higher end of this graph but why are the DSL customers occupying a good portion of the Optic Fiber territory?

# %%
sns.relplot(x = "MonthlyCharges", y = "TotalCharges", data=clean_df, hue="Churn", aspect=2, height=9, palette=["#088da5", "#8b0000"])

# %% [markdown]
# ### The bottom right of the graph has a high number of customers who have churned - probably because of the high monthly base plans (Fiber Optic). Also important to note this curved line of churned customers around the middle seems to have some non-linearity to it - in the favor of telling us that customers often churn while their Total Monthly charges are way way higher than their base prices.

# %%
sns.relplot(x = "MonthlyCharges", y = "TotalCharges", data=clean_df, hue="Churn", aspect=2, height=9, palette=["#088da5", "#8b0000"], style="InternetService")

# %%
sns.swarmplot(x = "Contract", y = "TotalCharges", data=clean_df, hue="Churn",  palette=["#00ffff", "#ff1493"])

# %% [markdown]
# ### Customers who are billed monthly seem to notorious for churning - especially if their total charges are extremely high! Longer term customers are more stable and they dont churn - most probably because of the contract limitations/penalties.

# %%
sns.swarmplot(x = "PaymentMethod", y = "TotalCharges", data=clean_df, hue="Churn", palette=["#00ffff", "#ff1493"])

# %% [markdown]
# ### A higher proportion of the customers who have opted for the electronic cheque payment system churn as compared to the other payment systems

# %%
sns.swarmplot(x = "Partner", y = "TotalCharges", data=clean_df, hue="Churn", palette=["#00ffff", "#ff1493"])

# %% [markdown]
# ### Customers who are single have a higher churn percentage than couples. This applies for both low bills and extremely high ones.

# %%
sns.swarmplot(x = "gender", y = "TotalCharges", data=clean_df, hue="Churn", palette=["#00ffff", "#ff1493"])

# %% [markdown]
# ### Female customers who had a mid-range bill have a higher chance of churning as compared to their male counterparts

# %%
sns.relplot(x = "MonthlyCharges", y = "TotalCharges", data=clean_df, hue="Churn", aspect=2, height=9, palette=["#6dc066", "#660066"], style="Contract")

# %% [markdown]
# ### An interesting takeaway here is that customers with lower monthly payments usually take the longer 2 year contract and these customers dont usually churn (as we discussed earlier) becuase of the contract limitations/penalities. However, Customers with higher monthly plans not only opt for month to month payments but also have a higher probability of churning.

# %%
final.to_pickle('final_df.pkl')
